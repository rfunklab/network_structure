# %%
import os
os.chdir('/home/gebhart/projects/rfunklab/network_structure')
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval as make_tuple
from network_structure.homology_parser import *
import persim

# %%
graph_type = 'knowledge'
knowl_data_loc = '/home/gebhart/projects/rfunklab/data/temporal/aps/1_1/knowledge/homology'

# %%
def interval_to_numpy(interval):
    '''Helper function to convert parsed homology interval to numpy array'''
    if len(interval) > 1:
        return np.array([list(ival) if len(ival) > 1 else [ival[0],np.inf] for ival in interval])            
    return np.array([])

# %%
def plot_diagram(diagram, title='', lims=None):
    '''Plots persistence diagram'''
    fig, ax = plt.subplots()
    if diagram.size > 0:
        d = diagram[~np.isinf(diagram[:,1])]
        if d.shape[0] > 0:
            ax.scatter(d[:,0], d[:,1], s=25, c=d[:,1]**2 - d[:,0], cmap=plt.cm.coolwarm, zorder=10)
            if lims is None:
                lims = [
                    np.min(d[:,0]-1),  # min of both axes
                    np.max(d[:,1]+1),  # max of both axes
                ]

            # now plot both limits against eachother
            ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
            ax.set_xlim(lims)
            ax.set_ylim(lims)
    ax.set_aspect('equal')
    plt.xlabel('Birth')
    plt.ylabel('Death')
    plt.title(title)

# %%
# read all .homology files within directory
files = [f for f in os.listdir(knowl_data_loc) if os.path.isfile(os.path.join(knowl_data_loc, f))]
files.sort()

# %%
# this code block reads the betti numbers, cell counts, and homology information from the .homology files. 
# Set the `doi` variable to change the dimension whose persistence diagram will be  plotted for each year.
# If homology is trivial in that dimension for a given year, nothing will be plotted. 
# Betti numbers and cell counts are printed out, each index in the printed array corresponds to a dimension (starting at 0). 

doi = 5 # the "dimension of interest" to plot persistence diagrams

npints = []
names = []
bettis = []
cell_counts = []
for file in files:
    yr = file[:4]
    print(yr)
    try:
        knowl_intervals = parse_intervals(os.path.join(knowl_data_loc, file))
        knowl_bettis = parse_betti(os.path.join(knowl_data_loc,file))
        knowl_cell_counts = parse_cell_counts(os.path.join(knowl_data_loc,file))
    except IndexError:
        continue
    names.append(yr)
    print('Betti Numbers: ', knowl_bettis)
    print('Cell Counts: ', knowl_cell_counts)
    bettis.append(knowl_bettis)
    cell_counts.append(knowl_cell_counts)
    ints = []
    for i in range(len(knowl_intervals)):
        knowl_npint = interval_to_numpy(knowl_intervals[i])
        ints.append(knowl_npint)
        if i == doi:
            if knowl_npint.size > 0:
                plot_diagram(knowl_npint, title='{} Knowledge Dimension {}'.format(yr, i))
            plt.show()
    npints.append(ints)
# Out:
# 1970
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]
# 1971
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]
# 1972
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]
# 1973
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]
# 1974
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]
# 1975
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]
# 1976
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]
# 1977
# Betti Numbers:  [4, 0, 0]
# Cell Counts:  [10, 8, 2, 0]
# 1978
# Betti Numbers:  [10, 0, 0]
# Cell Counts:  [26, 21, 5, 0]
# 1979
# Betti Numbers:  [8, 0, 0]
# Cell Counts:  [24, 22, 6, 0]
# 1980
# Betti Numbers:  [19, 172, 0, 0, 0]
# Cell Counts:  [651, 1520, 881, 167, 2, 0]
# 1981
# Betti Numbers:  [12, 382, 3, 0, 0, 0, 0]
# Cell Counts:  [942, 3097, 2470, 819, 159, 24, 2, 0]
# 1982
# Betti Numbers:  [7, 470, 17, 0, 0, 0, 0]
# Cell Counts:  [1024, 3698, 3044, 949, 159, 28, 2, 0]
# 1983
# Betti Numbers:  [7, 406, 46, 0, 0, 0, 0]
# Cell Counts:  [1057, 4173, 3929, 1358, 211, 20, 1, 0]
# 1984
# Betti Numbers:  [4, 420, 42, 0, 0, 0, 0]
# Cell Counts:  [1040, 4431, 4596, 2051, 568, 102, 6, 0]
# 1985
# Betti Numbers:  [4, 360, 657, 24, 0, 0, 0, 0, 0]
# Cell Counts:  [1317, 10593, 22877, 23061, 14322, 6004, 1694, 301, 26, 0]
# 1986
# Betti Numbers:  [3, 367, 976, 192, 5, 0, 0, 0, 0, 0]
# Cell Counts:  [1497, 16148, 47510, 67612, 59247, 35226, 14671, 4218, 781, 80, 3]
# 1987
# Betti Numbers:  [1, 383, 966, 162, 9, 0, 0, 0, 0, 0]
# Cell Counts:  [1512, 17081, 51249, 75319, 68797, 42493, 18151, 5264, 984, 111, 6]
# 1988
# Betti Numbers:  [2, 383, 1056, 233, 6, 0, 0, 0, 0, 0]
# Cell Counts:  [1535, 18107, 57381, 90839, 90987, 62308, 29593, 9555, 1981, 230, 10]
# 1989
# Betti Numbers:  [2, 353, 1098, 253, 27, 0, 0, 0, 0, 0]
# Cell Counts:  [1551, 19088, 63601, 104178, 104187, 68478, 30756, 9651, 2089, 287, 19]
# 1990
# Betti Numbers:  [1, 342, 1237, 324, 12, 0, 0, 0, 0, 0]
# Cell Counts:  [1545, 19279, 65444, 110275, 118790, 90211, 49835, 19957, 5677, 1117, 140]
# 1991
# Betti Numbers:  [3, 328, 1114, 355, 8, 0, 0, 0, 0, 0]
# Cell Counts:  [1538, 19937, 72095, 131622, 151819, 120425, 68272, 28315, 8726, 1997, 312]
# 1992
# Betti Numbers:  [3, 305, 1220, 479, 34, 0, 0, 0, 0, 0]
# Cell Counts:  [1658, 23239, 93373, 189511, 241236, 210285, 130106, 57093, 17207, 3311, 343]
# 1993
# Betti Numbers:  [2, 320, 1415, 624, 47, 3, 0, 0, 0, 0]
# Cell Counts:  [1876, 27452, 117669, 257116, 355938, 337277, 223975, 104671, 34202, 7636, 1095]
# 1994
# Betti Numbers:  [2, 302, 1286, 701, 138, 4, 0, 0, 0, 0]
# Cell Counts:  [1982, 29883, 137648, 327044, 483448, 483625, 344810, 181419, 72463, 22655, 5637]
# 1995
# Betti Numbers:  [2, 323, 1386, 779, 113, 1, 0, 0, 0, 0]
# Cell Counts:  [2088, 31285, 143167, 337083, 495411, 499948, 367464, 202630, 84340, 26151, 5801]
# 1996
# Betti Numbers:  [2, 401, 1373, 602, 67, 0, 0, 0, 0, 0]
# Cell Counts:  [2244, 31932, 137996, 307965, 432656, 418377, 295229, 159730, 69142, 24527, 7033]
# 1997
# Betti Numbers:  [5, 388, 1382, 679, 71, 2, 0, 0, 0, 0]
# Cell Counts:  [2387, 32816, 147601, 351317, 534551, 564015, 431583, 247107, 108368, 36787, 9504]
# 1998
# Betti Numbers:  [7, 327, 1364, 692, 76, 0, 0, 0, 0, 0]
# Cell Counts:  [2471, 35890, 173102, 448589, 748973, 866831, 720094, 437125, 195659, 64597, 15471]
# 1999
# Betti Numbers:  [5, 362, 1547, 707, 160, 7, 0, 0, 0, 0]
# Cell Counts:  [2423, 38448, 192107, 515615, 885982, 1049106, 900420, 584797, 298746, 123174, 40881]
# 2000
# Betti Numbers:  [7, 376, 1570, 836, 168, 10, 0, 0, 0, 0]
# Cell Counts:  [2429, 40305, 210144, 589117, 1069313, 1365307, 1291815, 942482, 547537, 257915, 97934]
# 2001
# Betti Numbers:  [4, 404, 1917, 878, 162, 17, 1, 0, 0, 0]
# Cell Counts:  [2661, 43440, 221691, 621453, 1168477, 1593506, 1647755, 1333003, 864103, 456497, 198051]
# 2002
# Betti Numbers:  [7, 463, 1903, 855, 173, 6, 2, 0, 0, 0]
# Cell Counts:  [2797, 44421, 221698, 617218, 1166260, 1609841, 1682329, 1354689, 846295, 409656, 152371]
# 2003
# Betti Numbers:  [4, 590, 2566, 1126, 179, 9, 0, 0, 0, 0]
# Cell Counts:  [2968, 47212, 216878, 534559, 887962, 1087499, 1026148, 760610, 443541, 201091, 69128]
# 2004
# Betti Numbers:  [8, 717, 2748, 1117, 146, 6, 0, 0, 0, 0]
# Cell Counts:  [3331, 51309, 225943, 529313, 832689, 976756, 910797, 698289, 440427, 223000, 87439]
# 2005
# Betti Numbers:  [17, 667, 2574, 1154, 219, 8, 0, 0, 0, 0]
# Cell Counts:  [3544, 55111, 272094, 743718, 1391168, 1961162, 2199675, 2003751, 1476476, 868339, 401703]
# 2006
# Betti Numbers:  [20, 550, 1875, 1093, 238, 48, 1, 0, 0, 0]
# Cell Counts:  [3471, 55647, 323906, 1097838, 2534096, 4251995, 5398026, 5339262, 4211986, 2704778, 1440411]
# 2007
# Betti Numbers:  [6, 465, 1742, 1206, 402, 56, 4, 1, 0, 0]
# Cell Counts:  [3046, 55206, 341667, 1228581, 3027332, 5463235, 7464933, 7862928, 6446738, 4127887, 2057748]
# 2008
# Betti Numbers:  [4, 651, 2604, 1126, 257, 64, 5, 0, 0, 0]
# Cell Counts:  [3490, 60005, 343883, 1211158, 3076531, 5880683, 8687672, 10131453, 9469013, 7165606, 4420152]
# 2009
# Betti Numbers:  [3, 723, 2534, 1046, 286, 47, 7, 0, 0, 0]
# Cell Counts:  [3477, 59899, 342846, 1226356, 3183986, 6219862, 9336823, 10925739, 10044892, 7272207, 4133666]
# 2010
# Betti Numbers:  [4, 923, 3721, 1469, 439, 68, 3, 0, 0, 0]
# Cell Counts:  [3792, 65461, 335755, 1010620, 2099831, 3136185, 3479651, 2951936, 1951723, 1010368, 403362]
# 2011
# Betti Numbers:  [2, 629, 2771, 980, 262, 50, 8, 1, 0, 0]
# Cell Counts:  [3413, 62233, 365190, 1314264, 3377583, 6413813, 9217356, 10237063, 8936747, 6204416, 3437204]
# 2012
# Betti Numbers:  [2, 607, 2711, 820, 159, 28, 3, 0, 0, 0]
# Cell Counts:  [3487, 63608, 387102, 1496971, 4242925, 9072863, 14993066, 19547534, 20387213, 17137377, 11640227]
# 2013
# Betti Numbers:  [3, 595, 2543, 697, 153, 36, 7, 1, 0, 0]
# Cell Counts:  [3482, 62647, 385509, 1530909, 4452259, 9690702, 16150821, 21065322, 21842367, 18164626, 12147415]
# 2014
# Betti Numbers:  [2, 580, 2467, 869, 230, 60, 6, 0, 0, 0]
# Cell Counts:  [3414, 60127, 362460, 1398840, 3918921, 8132687, 12793692, 15637606, 15162509, 11844902, 7528175]
# 2015
# Betti Numbers:  [2, 650, 2319, 746, 247, 59, 7, 0, 0, 0]
# Cell Counts:  [3378, 58739, 353809, 1369621, 3823811, 7904488, 12471009, 15431526, 15241427, 12102434, 7716909]
# 2016
# Betti Numbers:  [4, 797, 1579, 451, 60, 5, 0, 0, 0, 0]
# Cell Counts:  [3044, 36712, 142703, 342275, 585876, 736640, 703342, 529373, 324791, 166356, 71331]
# 2017
# Betti Numbers:  [0, 0]
# Cell Counts:  [0, 0, 0]

# %%
# plot betti numbers for each year
betti_up_to_dimension = 10 # set this as the highest dimension to plot (max is 10).

for d in range(betti_up_to_dimension):
    plt.plot(names, [b[d] if len(b) > d else 0 for b in bettis])
    plt.xticks(rotation=60)
    plt.ylabel('Betti_{}'.format(d))
    plt.xlabel('Year')
    plt.title('Betti Number Dimension {}'.format(d))
    plt.show()

# %%
# plot cell counts for each year
cc_up_to_dimension = 11 # set this as the highest dimension to plot (max is 11).

for d in range(cc_up_to_dimension):
    plt.plot(names, [c[d] if len(c) > d else 0 for c in cell_counts])
    plt.xticks(rotation=60)
    plt.ylabel('Cell Count'.format(d))
    plt.xlabel('Year')
    plt.title('Cell Count Dimension {}'.format(d))
    plt.show()

# %%
# Access the diagrams as numpy arrays in preparation for the following code block. 
doi = 1 # set this to compute Bottleneck and Wasserstein distances in particular "dimension of interest"

diags = []
for i in range(len(npints)):
    npint = npints[i]
    if len(npint) > doi:
        npdoi = npint[doi]
        diags.append(npdoi)
    else:
        diags.append(np.array([]))

# %%
# WARNING: This code block takes a lot of time to run (~10-45 min depending on `doi` and `yr_ref`).

# This code block computes Bottleneck and Wasserstein distances between each year's diagram and the 
# diagram corresponding to the year in `yr_ref`. This `yr_ref` variable is an integer indexing into
# the array of years, so, for example, yr_ref = 4 --> 1974 since yr_ref = 0 --> 1970. These distance 
# measures are well-defined over the space of persistence diagrams and can be though of as a measure 
# of how different the topology of two spaces are from each other within (or across, though this is 
# less common) dimensions. 

yr_ref = 11 # set this to use different year as reference year. 


bottlenecks = []
wassersteins = []
heats = []
for i in range(yr_ref,len(diags)):
    print('{}/{}'.format(i,len(diags)))
    if diags[i].size > 0:
        diags[i][diags[i] == np.inf] = 50
        bottlenecks.append(persim.bottleneck(diags[yr_ref], diags[i]))
        wassersteins.append(persim.sliced_wasserstein(diags[yr_ref], diags[i]))
#         heats.append(persim.heat(diags[yr_ref], diags[i]))
    else:
        bottlenecks.append(-1)
        wassersteins.append(-1)
#         heats.append(-1)
# Out:
# 11/48
# 12/48
# 13/48
# 14/48
# 15/48
# 16/48
# 17/48
# 18/48
# 19/48
# 20/48
# 21/48
# 22/48
# 23/48
# 24/48
# 25/48
# 26/48
# 27/48
# 28/48
# 29/48
# 30/48
# 31/48
# 32/48
# 33/48
# 34/48
# 35/48
# 36/48
# 37/48
# 38/48
# 39/48
# 40/48
# 41/48
# 42/48
# 43/48
# 44/48
# 45/48
# 46/48
# 47/48

# %%
# plot the bottleneck distances for each year with respect to a base year
plt.plot(names[yr_ref:], bottlenecks)
plt.xticks(rotation=60)
plt.ylabel('Bottleneck Distance')
plt.xlabel('Year')
plt.title('Bottleneck Distance ({} Reference)'.format(names[yr_ref]))
# Out:
# Text(0.5, 1.0, 'Bottleneck Distance (1981 Reference)')

# %%
# plot the wasserstein distances for each year with respect to a base year
plt.plot(names[yr_ref:], wassersteins)
plt.xticks(rotation=60)
plt.ylabel('Wasserstein Distance')
plt.xlabel('Year')
plt.title('Wasserstein Distance ({} Reference)'.format(names[yr_ref]))
# Out:
# Text(0.5, 1.0, 'Wasserstein Distance (1981 Reference)')
